# %% [markdown]
# <a href="https://colab.research.google.com/github/Tadashi-Nagashima/Projeto_Alura_Google_AI/blob/main/Projeto_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata

Google_API_KEY = userdata.get("SECRET_KEY")
genai.configure(api_key=Google_API_KEY)

generation_config = {
    "candidate_count": 1,
    "temperature": 0,
    "top_k": 22,

}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_LOW_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_LOW_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_LOW_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_LOW_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-1.0-pro", generation_config = generation_config, safety_settings = safety_settings)

prompt_parts = [
    "Formate as seguintes referências em ABNT",

    "Nome do(s) autor(es): Ana Cláudia Coelho",

    "Título: Fatores determinantes de qualidade de vida física e mental em pacientes com doença pulmonar intersticial: uma análise multifatorial.",

    "Ano de publicação: 2009",

    "Fonte (Título do periódico): Lume UFRGS",

    "Local: ",

    "Seção, caderno ou parte do jornal: ",

    "Número da edição: ",

    "Número do ano: ",

    "Página inicial-final: ",

    "Disponível em (link): http://www.lume.ufrgs.br/bitstream/handle/10183/16359/000695147.pdf?sequence=1 ",

    "Acesso em (dia, mês [três caracteres seguido de ponto final, com excecção de 'maio' que possui quatro caracteres] e ano [quatro caracteres]): 4 set. 2009",

    "DOI: ",

    "Formatação:\nCOELHO, A. C. Fatores determinantes de qualidade de vida física e mental empacientes com doença pulmonar intersticial: uma análise multifatorial, 2009. Disponível em:http://www.lume.ufrgs.br/bitstream/handle/10183/16359/000695147.pdf?sequence=1. Acesso em: 4 set. 2009.",
    ###
    "Nome do(s) autor(es): Gustavo Luiz Gonçalves Da Silva",

    "Título: Segurança Pública E Seus Desafios No Brasil",

    "Ano de publicação: 2019",

    "Fonte (Título do periódico): Repositório Institucional AEE",

    "Local: ",

    "Seção, caderno ou parte do jornal: ",

    "Número da edição: ",

    "Número do ano: ",

    "Página inicial-final: ",

    "Disponível em (link): http://repositorio.aee.edu.br/jspui/handle/aee/19451 ",

    "Acesso em (dia [dois caracteres], mês [três caracteres seguido de ponto final, com excecção de 'maio' que possui quatro caracteres] e ano [quatro caracteres]): 20 abr. 2024",

    "DOI: ",

    "Formatação:\nSILVA, G. L. G. Segurança pública e seus desafios No Brasil. Repositório Instituicional AEE, 2019. Disponível em: <http://repositorio.aee.edu.br/jspui/handle/aee/19451 >. Acesso em: 20 abr. 2024.",
    ###
    "Nome do(s) autor(es): Lu Aiko Otta",

    "Título: Parcela do Tesouro Nos Empréstimos Do BNDES Cresce 566 % em Oito Anos",

    "Ano de publicação: 2010",

    "Fonte (Título do periódico): O Estado de S. Paulo",

    "Local: São Paulo",

    "Seção, caderno ou parte do jornal: Economia & Negócios",

    "Número da edição: 42656",

    "Número do ano: 131",

    "Página inicial-final: B1",

    "Disponível em (link): ",

    "Acesso em (dia [dois caracteres], mês três caracteres seguido de ponto final, com excecção de 'maio' que possui quatro caracteres] e ano [quatro caracteres]): ",

    "DOI: ",

    "Formatação:\nOTTA, L. A. Parcela do tesouro nos empréstimos do BNDES cresce 566 % em oito anos. O Estado de S. Paulo, São Paulo, ano 131, n. 42656, 1 ago. 2010. Economia & Negócios, p. B1",

    ###
    "Nome do(s) autor(es): L. F. Veríssimo",

    "Título: Um Gosto pela ironia",

    "Ano de publicação: 2010",

    "Fonte (Título do periódico): Zero Hora ",

    "Local: ",

    "Seção, caderno ou parte do jornal: ",

    "Número da edição: 16.414",

    "Número do ano: 47",

    "Página inicial-final: 2",

    "Disponível em (link): http://www.clicrbs.com.br/zerohora/jsp/default.jspx?uf=1&action=flip",

    "Acesso em (dia [dois caracteres], mês [três caracteres seguido de ponto final, com excecção de 'maio' que possui quatro caracteres] e ano [quatro caracteres]): 12 ago. 2010",

    "DOI: ",

    "Formatação:\nVERÍSSIMO, L. F. Um gosto pela ironia. Zero Hora, Porto Alegre, ano 47, n. 16.414, p. 2, 2010. Disponível em: http://www.clicrbs.com.br/zerohora/jsp/default.jspx?uf=1&action=flip. Acesso em: 12 ago. 2010.",
    ###
    "Nome do(s) autor(es): Antônio Augusto Moura da Silva "

    "Título: Intervenções Precoces Para a Redução de Vulnerabilidades e Melhora do Desenvolvimento Infantil",

    "Ano de publicação: 2019",

    "Fonte (Título do periódico): Cadernos de Saúde Pública",

    "Local: Rio de Janeiro",

    "Seção, caderno ou parte do jornal: ",

    "Número da edição: ",

    "Número do ano: ",

    "Página inicial-final: 1-3",

    "Disponível em (link): https://www.scielosp.org/article/csp/2019.v35n3/e00030519/",

    "Acesso em (dia [dois caracteres], mês [três caracteres seguido de ponto final, com excecção de 'maio' que possui quatro caracteres] e ano [quatro caracteres]): 30 nov. 2023",

    "DOI: https://doi.org/10.1590/0102-311X00030519",

    "Formatação:\nSILVA, A. A. M. Intervenções precoces para a redução de vulnerabilidades e melhora do desenvolvimento infantil. Cadernos de Saúde Pública, Rio de Janeiro, p. 1-3, 2019. DOI https://doi.org/10.1590/0102-311X00030519. Disponível em: https://www.scielosp.org/article/csp/2019.v35n3/e00030519/. Acesso em: 30 nov. 2023.",
    ###
    "Nome do(s) autor(es): "

    "Título: ",

    "Ano de publicação: ",

    "Fonte (Título do periódico): ",

    "Local: ",

    "Seção, caderno ou parte do jornal: ",

    "Número da edição: ",

    "Número do ano: ",

    "Página inicial-final:",

    "Disponível em (link):",

    "Acesso em (dia [dois caracteres], mês [três caracteres seguido de ponto final, com excecção de 'maio' que possui quatro caracteres] e ano [quatro caracteres]): ",

    "DOI:",

    "Formatação:\nDados não informados.",
    ###
    input("Nome do(s) autor(es): "),

    titulo := input("Título: "),

    input("Ano de publicação: "),

    input("Fonte (Título do periódico): "),

    input("Local: "),

    input("Seção, caderno ou parte do jornal: "),

    input("Número da edição: "),

    input("Número do ano: "),

    input("Página inicial-final: "),

    input("Disponível em (link): "),

    input("Acesso em (dia [dois caracteres], mês [três caracteres seguido de ponto final, com excecção de 'maio' que possui quatro caracteres] e ano [quatro caracteres]): "),

    input("DOI: "),

    "Formatação:\n",
    ]
    ###

if not titulo:
    print("\nDados essenciais não informados.")
else:
    response = model.generate_content(prompt_parts)
    print(response.text)
# Out:
# Nome do(s) autor(es): gustavo camargo
# Título: o essencial estudo
# Ano de publicação: 2020
# Fonte (Título do periódico):
# Local:
# Seção, caderno ou parte do jornal:
# Número da edição:
# Número do ano:
# Página inicial-final:
# Disponível em (link):
# Acesso em (dia [dois caracteres], mês [três caracteres seguido de ponto final] e ano [quatro caracteres]): 20 maio. 2020
# DOI:
# CAMARGO, G. O essencial estudo. 20 maio. 2020.
